# %% [markdown]
# # Linking the illegal books data
# Author: Michael Falk
# ## The problem
# In the processing of joining the different tables in the MPCE data, it has become apparent that most of the banned books do not have superbook codes. This makes it impossible at the moment to link the rows in the  'manuscripts_titles_illegal' table to any of the other tables in the database.
# ## The proposed solution
# In this notebook, I try to use the `dedupe` library to efficiently find matches between the illegal titles and the titles in the superbooks table.

# %%
import pandas as pd
import dedupe as dd
# Data was preprocessed in R.
# Read in the csv:
df = pd.read_csv("data/reduced_super_book.csv")
# Replace 'Nan' with 'None' object (required by Dedupe)
df = df.where((pd.notnull(df)), None)
# Convert into dictionary of records
data = df.to_dict(orient="index")
# Create a variables dictionary for Dedupe to work with
variables = [
    {'field':'primary_author_name','type':'String'},
    {'field':'full_book_title','type':'String'}
]
# Initialise deduplication object
deduper = dd.Dedupe(variables)

# %% [markdown]
# Now the data is in the form of a dictionary, with each field labelled:

# %%
from itertools import islice
dict(list(data.items())[10000:10003])
# Out:
# {10000: {'UUID': '78039d15-eda0-4fb8-b77d-2eb8b5616ca8',
#   'super_book_code': None,
#   'primary_author_name': 'Luzac, Elie',
#   'full_book_title': 'Essai sur la liberte de produire ses sentiments',
#   'stated_publication_years': None,
#   'illegal_date': '1749'},
#  10001: {'UUID': '76eebf56-87bf-4fc3-9f6b-41ef48238ad2',
#   'super_book_code': 'spbk0000580',
#   'primary_author_name': 'Abauzit, Firmin;',
#   'full_book_title': "Discours historique sur l'apocalypse <spbk0000580>",
#   'stated_publication_years': None,
#   'illegal_date': '1779'},
#  10002: {'UUID': '6ed7ba9c-158d-41cb-9b42-e548d3bf2874',
#   'super_book_code': None,
#   'primary_author_name': 'Du Laurens, Henri Joseph',
#   'full_book_title': "L'Aretin",
#   'stated_publication_years': None,
#   'illegal_date': '1778'}}

# %%
# Now train the model
deduper.sample(data, 150000, .5) # This randomly generates 150000 pairs of records to compare
deduper.train() # Trains the model to work out which pairs are the same
deduper.cleanupTraining() # Delete variables used for training from the memory
# Out:
# [{'super_book_code': 'spbk0000004',
#   'primary_author_name': 'Boutet de Monvel, Jacques-Marie',
#   'full_book_title': "Trois (les) Fermiers, comédie en 2 actes en prose et mêlée d'ariettes, représentée pour la première fois par les Comédiens italiens ordinaires du Roi, le 16 mai 1777",
#   'stated_publication_years': '1777',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000005',
#   'primary_author_name': 'Dreamer, Oliver',
#   'full_book_title': "Paix de 1782, ou le Bowl de punch, de Master Oliver Dreamer, traduit de l'anglois, d'après la 5e édition [la]",
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000006',
#   'primary_author_name': nan,
#   'full_book_title': "A quoi sert un titre, si l'ouvrage est bon?",
#   'stated_publication_years': '1787',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000007',
#   'primary_author_name': 'Voltaire, François Marie Arouet',
#   'full_book_title': "A.B.C. (l'), dialogue curieux",
#   'stated_publication_years': '1769',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000011',
#   'primary_author_name': 'Superville, Daniel [de]',
#   'full_book_title': "Elemens du christianisme, ou Abrégé des véritez et des devoirs de la religion chrétienne à l'usage des enfans",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000012',
#   'primary_author_name': 'Palairet, Jean',
#   'full_book_title': 'Abrégé sur les sciences et sur les arts, par demandes et par réponses',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000014',
#   'primary_author_name': 'Rist, Jean',
#   'full_book_title': "Abrégé méthodique des principes d'anatomie et de chirurgie: pour faciliter l'étude de cette science aux élèves, & y entretenir ceux qui la possédent déja",
#   'stated_publication_years': '1767',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000015',
#   'primary_author_name': 'La Lande, Jérôme [de]',
#   'full_book_title': "Abrégé d'astronomie, par M. de La Lande",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000016',
#   'primary_author_name': 'Pfeffel von Kriegelstein, Christian Friedrich',
#   'full_book_title': "Abrégé chronologique de l'histoire et du droit public d'Allemagne, par M. Pfeffel",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000017',
#   'primary_author_name': 'Racine, Bonaventure',
#   'full_book_title': "Abrégé de l'histoire ecclésiastique, contenant les événemens considérables de chaque siecle; avec des réflexions",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000021',
#   'primary_author_name': 'Ostervald, Jean-Frédéric',
#   'full_book_title': "[Abrégé de l'histoire sainte et du catéchisme]",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000022',
#   'primary_author_name': 'Diderot, Denis',
#   'full_book_title': 'Abrégé du code de la nature',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000024',
#   'primary_author_name': 'Chavanette, Perrin de',
#   'full_book_title': "Abrégé portatif de l'histoire universelle sacrée et profane pour l'instruction de la jeunesse, par l'abbé Perrin de Chavanette",
#   'stated_publication_years': '1778',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000025',
#   'primary_author_name': 'Du Laurens, Henri-Joseph',
#   'full_book_title': 'Vérité (la). Vertu et vérité. Le cri de Jean-Jacques et le mien ',
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000026',
#   'primary_author_name': 'Bellecour, abbé',
#   'full_book_title': 'Académie universelle des jeux: contenant les regles des jeux de cartes permis; celles du billard, du mail, du trictrac, du revertier, &c. &c. avec des instructions faciles pour apprendre à les bien jouer',
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000026',
#   'primary_author_name': 'Bellecour, abbé',
#   'full_book_title': "Académie universelle des jeux, contenant les regles de tous les jeux, avec des instructions faciles pour apprendre à les bien jouer. Nouvelle édition, augmentée du jeu des echecs, par Philidor, & du jeu du whisk, par Edmond Hoyle, traduit de l'anglois",
#   'stated_publication_years': '1777',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000028',
#   'primary_author_name': 'Longchamps, Pierre [de]',
#   'full_book_title': 'Soeur (la) Adelaïde, ses égarements, ses vertus, ses foiblesses et son repentir: ouvrage posthume du plus éloquent écrivain de ce siècle',
#   'stated_publication_years': '1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000029',
#   'primary_author_name': 'Robert, Louise-Félicité Guinement de Keralio, madame',
#   'full_book_title': 'Adelaïde, ou Mémoires de la marquise de M***',
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000029',
#   'primary_author_name': 'Robert, Louise-Félicité Guinement de Keralio, madame',
#   'full_book_title': 'Adelaïde, ou Mémoires de la marquise de M*** écrits par elle-même',
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000031',
#   'primary_author_name': 'Fonson, Michel J.',
#   'full_book_title': 'Adieux de soeur Rose à son cloître',
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000032',
#   'primary_author_name': 'Necker, Jacques',
#   'full_book_title': "Administration (de l') des finances de la France",
#   'stated_publication_years': '1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000033',
#   'primary_author_name': 'Pellissery, Roch-Antoine [de]',
#   'full_book_title': 'Administration politique de Colbert: ouvrage qui par son érudition, ses principes économiques, calculs politiques &c. peut servir de repertoire universel des connoissances nécessaires à ses administrateurs',
#   'stated_publication_years': '1776',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000034',
#   'primary_author_name': 'Saint-Victor, Guillemain [de]',
#   'full_book_title': 'Adoption, ou la maçonnerie des femmes en trois gradés',
#   'stated_publication_years': '100070075',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000035',
#   'primary_author_name': 'Genlis, Stéphanie Félicité [comtesse de]',
#   'full_book_title': "Adèle et Théodore ou Lettres sur l'éducation, contenant tous les principes relatifs aux trois différens plans d'éducation des princes, des jeunes personnes, & des hommes  ",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000036',
#   'primary_author_name': 'Genlis, Stéphanie Félicité [comtesse de]',
#   'full_book_title': 'Agar dans le desert, comédie',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000038',
#   'primary_author_name': 'Alletz, Pons Augustin',
#   'full_book_title': "Agronome (l'), ou Dictionnaire portatif du cultivateur",
#   'stated_publication_years': '1780',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000039',
#   'primary_author_name': 'Albert le Grand',
#   'full_book_title': "Admirables (les) Secrets d'Albert le Grand, contenant plusieurs traités sur la conception des femmes et les vertus des herbes, des pierres précieuses, etc.",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000040',
#   'primary_author_name': 'Alletz, Pons Augustin',
#   'full_book_title': "Albert (l') moderne, ou nouveaux secrets éprouvés et licites, recueillis d'après les découvertes les plus récentes",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000042',
#   'primary_author_name': nan,
#   'full_book_title': 'Secrets merveilleux de la magie naturelle et cabalistique du petit Albert',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000043',
#   'primary_author_name': 'Abbizzi de Pise, Barthélemy',
#   'full_book_title': "Alcoran (l') des Cordeliers, tant en latin qu'en français, ou recueil des plus notables bourdes et blasphèmes impudents de ceux qui ont osé comparer S. François à Jésus-Christ, tiré du grand livre des conformités, jadis composé par frère Barthélemy de Pise, Cordelier en son vivant",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000044',
#   'primary_author_name': 'Zannowich, Stephano',
#   'full_book_title': "Stiepan-Annibale d'Albanie a Fréderic-Guillaume de Prusse. Epître pathétique, philosophique, historique, &c., ou, L'Alcoran des princes destinés au trone",
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000045',
#   'primary_author_name': 'Haller, Albrecht [von]',
#   'full_book_title': 'Alfred, Roi des Anglo-Saxons... Traduit de l’Allemand (par C. P.)',
#   'stated_publication_years': '1775',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000046',
#   'primary_author_name': 'Guillard de Beaurieu, Gaspard',
#   'full_book_title': "Allaitement (de l') et de la premiere éducation des enfans, par l'auteur de l'Éleve de la nature",
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000047',
#   'primary_author_name': nan,
#   'full_book_title': 'Almanach de Neuchâtel',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000048',
#   'primary_author_name': nan,
#   'full_book_title': 'Almanach royal',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000050',
#   'primary_author_name': nan,
#   'full_book_title': 'Almanach de Cabinet',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000052',
#   'primary_author_name': 'Bérenger, Jean-Pierre',
#   'full_book_title': 'Amans (les) républicains: ou Lettres de Nicias et Cynire.',
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000053',
#   'primary_author_name': 'Hélaine [abbé]',
#   'full_book_title': "Amans (les) vertueux, ou Lettres d'une jeune dame écrites de la campagne à son amie de Londres",
#   'stated_publication_years': '1774',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000054',
#   'primary_author_name': 'Genlis, Stéphanie Félicité [comtesse de]',
#   'full_book_title': "Amant (l') anonyme: comédie en cinq actes",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000055',
#   'primary_author_name': "Arnaud, François-Thomas-Marie de Baculard [d']",
#   'full_book_title': 'Amans (les) malheureux, ou le Comte de Comminge, drame en trois actes et en vers',
#   'stated_publication_years': '1774',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000056',
#   'primary_author_name': 'Baudrand, Barthélemi',
#   'full_book_title': "Ame (l') élevée à Dieu par les réflexions et les sentiments pour chaque jour du mois  ",
#   'stated_publication_years': '1777',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000057',
#   'primary_author_name': 'Le Prince de Beaumont, Marie',
#   'full_book_title': 'Américaines (les), ou La Preuve de la religion chrétienne par les lumières naturelles',
#   'stated_publication_years': '1770-1771',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000058',
#   'primary_author_name': 'Mouhy, Charles de Fieux',
#   'full_book_title': "Ami de la vertu, ou Mémoires et aventures de Monsieur d'Argicourt",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000059',
#   'primary_author_name': 'Roy, Jean',
#   'full_book_title': "Ami (l') des vieillards, présenté au Roi, par M. l'abbé Roy",
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000063',
#   'primary_author_name': 'Marivaux, Martin [de]',
#   'full_book_title': "Ami (l') des lois",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000066',
#   'primary_author_name': 'Fielding, Sarah',
#   'full_book_title': 'Vie (la) de David Simple',
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000067',
#   'primary_author_name': nan,
#   'full_book_title': "Ami de l'adolescence",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000069',
#   'primary_author_name': 'Berquin, Arnaud',
#   'full_book_title': "Ami (l') des enfans",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000073',
#   'primary_author_name': 'Rowe, Elizabeth Singer',
#   'full_book_title': "Amitié (l') après la mort, contenant les lettres des morts aux vivans et les lettres morales et amusantes",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000074',
#   'primary_author_name': nan,
#   'full_book_title': 'Amitié fraternelle, ou Le Triomphe des vertus',
#   'stated_publication_years': '1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000075',
#   'primary_author_name': nan,
#   'full_book_title': "Amours (les) et les aventures du Lord Fox. Traduits de l'anglois par M***",
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000076',
#   'primary_author_name': nan,
#   'full_book_title': 'Amours (les) de Charlot et Toinette, pièce dérobée à V***',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000078',
#   'primary_author_name': 'Sacy, Claude-Louis-Michel [de]',
#   'full_book_title': 'Amours (les) de Sapho et de Phaon',
#   'stated_publication_years': '1775',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000079',
#   'primary_author_name': 'Longus',
#   'full_book_title': 'Amours (les) de Daphnis et Chloé. Traduction de 1782',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000080',
#   'primary_author_name': "d'Emèse, Héliodore",
#   'full_book_title': 'Amours de Théagènes et Chariclée, histoire éthiopique',
#   'stated_publication_years': '1743',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000081',
#   'primary_author_name': 'Crébillon, Claude Prosper Jolyot de',
#   'full_book_title': "Amours (les) de Zeokinizul roi des Kofirans. Ouvrage traduit de l'arabe du voyageur Krinelbol",
#   'stated_publication_years': '1779',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000083',
#   'primary_author_name': 'Carmontelle, Louis Carrogis [de]',
#   'full_book_title': 'Amusemens de société, ou Proverbes dramatiques',
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000084',
#   'primary_author_name': 'Limbourg, Jean Philippe [de]',
#   'full_book_title': 'Amusemens (les) de Spa',
#   'stated_publication_years': '1782-1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000085',
#   'primary_author_name': 'Pinetti, Giuseppe',
#   'full_book_title': "Amusemens physiques et différentes expériences divertissantes, composées et exécutées tant à Paris que dans les diverses cours de l'Europe par le sieur Joseph Pinetti",
#   'stated_publication_years': '1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000086',
#   'primary_author_name': "Buc'hoz, Pierre-Joseph",
#   'full_book_title': "Amusemens des dames dans les oiseaux de volière, ou traité des oiseaux qui peuvent servir d'amusement au beau sexe",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000088',
#   'primary_author_name': nan,
#   'full_book_title': 'Amusemens du beau-sexe, ou Nouvelles Historiques et avantures galantes, tragiques, et comiques',
#   'stated_publication_years': '1773-1774',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000089',
#   'primary_author_name': 'Bougeant, Guillaume-Hyacinthe',
#   'full_book_title': 'Amusement philosophique sur le langage des bêtes',
#   'stated_publication_years': '1753',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000090',
#   'primary_author_name': 'Fielding, Henry',
#   'full_book_title': 'Amélie Booth: histoire angloise',
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000090',
#   'primary_author_name': 'Fielding, Henry',
#   'full_book_title': 'Amélie, histoire angloise',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000091',
#   'primary_author_name': 'Mercier, Louis-Sébastien',
#   'full_book_title': "[An (l') deux mille quatre cent quarante]",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000091',
#   'primary_author_name': 'Mercier, Louis-Sébastien',
#   'full_book_title': "An (l') deux mille quatre cent quarante: rêve s'il en fût jamais",
#   'stated_publication_years': '1772',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000091',
#   'primary_author_name': 'Mercier, Louis-Sébastien',
#   'full_book_title': "An deux mille quatre cent quarante (l'), rêve s'il en fût jamais",
#   'stated_publication_years': '1774',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000091',
#   'primary_author_name': 'Mercier, Louis-Sébastien',
#   'full_book_title': "[An (l') deux mille quatre cent quarante]",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000092',
#   'primary_author_name': 'Daquin, Joseph',
#   'full_book_title': "Analyse des eaux thermales d'Aix-en-Savoie, dans laquelle on expose les diverses manières d'user de ces eaux... et les différentes maladies pour lesquelles elles sont employées... par M. Joseph Daquin",
#   'stated_publication_years': '1773',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000093',
#   'primary_author_name': 'Marsy, François-Marie [de]',
#   'full_book_title': 'Abrégé du dictionnaire de Bayle',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000094',
#   'primary_author_name': 'Gilibert, Jean-Emmanuel',
#   'full_book_title': "Anarchie (l') médicinale, ou La Médicine considérée comme nuisable à la société",
#   'stated_publication_years': '1772',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000095',
#   'primary_author_name': 'Restif de la Bretonne, Nicolas-Edmé',
#   'full_book_title': "Andrographe (l'), ou Idées d'un honnête homme sur un projet de règlement proposé à toutes les nations de l'Europe pour opérer une réforme générale des moeurs et, par elle, le bonheur du genre humain",
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000096',
#   'primary_author_name': 'Gorsas, Antoine-Joseph',
#   'full_book_title': "Ane (l') promeneur, ou Critès promené par son ane; chef-d'oeuvre pour servir d'Apologie au goût, aux moeurs, à l'esprit, et aux découvertes du siècle. Première edition revue, corrigée, et précédée d'une préface à la mosaïque, dans le plus nouveau goût",
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000097',
#   'primary_author_name': 'Hornot, Antoine',
#   'full_book_title': 'Anecdotes américaines, ou Histoire abrégée des principaux événements arrivés dans le Nouveau monde',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000098',
#   'primary_author_name': 'Perrault',
#   'full_book_title': "Anecdotes originales de Pierre le Grand recueillies de la conversation de diverses personnes de distinction de St-Pétersbourg et de Moscou, par M. de Staehlin... Ouvrage traduit de l'allemand",
#   'stated_publication_years': '1787',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000100',
#   'primary_author_name': 'Clément, Jean Marie Bernard de Dijon',
#   'full_book_title': 'Anecdotes dramatiques',
#   'stated_publication_years': '1775',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000100',
#   'primary_author_name': 'Clément, Jean Marie Bernard de Dijon',
#   'full_book_title': 'Anecdotes dramatiques',
#   'stated_publication_years': '1775',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000101',
#   'primary_author_name': 'Imbert de Boudeaux, Guillaume',
#   'full_book_title': 'Anecdotes du XVIII Siècle',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000102',
#   'primary_author_name': 'Fabrice, Friedrich Ernst [bon von]',
#   'full_book_title': "Anecdotes du séjour du roi de Suède à Bender, ou Lettres de M. le Bon de Fabrice pour servir d'éclaircissement à l'histoire de Charles XII",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000104',
#   'primary_author_name': 'Pidansat de Mairobert, Mathieu-François',
#   'full_book_title': 'Anecdotes sur Mme la comtesse du Barry',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000105',
#   'primary_author_name': 'Rochette de La Morlière, Charles-Jacques-Louis-Auguste',
#   'full_book_title': 'Angola, histoire indienne; ouvrage sans vrai-semblance',
#   'stated_publication_years': '1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000105',
#   'primary_author_name': 'Rochette de La Morlière, Charles-Jacques-Louis-Auguste',
#   'full_book_title': 'Angola, histoire indienne: ouvrage sans vraisemblance',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000106',
#   'primary_author_name': nan,
#   'full_book_title': 'Anleitung zu dem Landbau, nach Erfahrungen',
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000107',
#   'primary_author_name': 'Malarme, Charlotte de Bournon [comtesse de]',
#   'full_book_title': 'Anna Rose-Tree, histoire anglaise par Mad. Malarme',
#   'stated_publication_years': '1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000108',
#   'primary_author_name': 'Linguet, Simon-Nicolas-Henri',
#   'full_book_title': 'Annales civiles, politiques et littéraires',
#   'stated_publication_years': '1778-1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000108',
#   'primary_author_name': 'Linguet, Simon-Nicolas-Henri',
#   'full_book_title': 'Annales civiles, politiques et littéraires',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000109',
#   'primary_author_name': 'Voltaire, François Marie Arouet',
#   'full_book_title': "Annales de l'Empire depuis Charlemagne jusqu'à nos jours",
#   'stated_publication_years': '1780',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000109',
#   'primary_author_name': 'Voltaire, François Marie Arouet',
#   'full_book_title': "Annales de l'Empire depuis Charlemagne",
#   'stated_publication_years': '1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000110',
#   'primary_author_name': 'Genlis, Stéphanie Félicité [comtesse de]',
#   'full_book_title': "Annales de la vertu, ou Cours d'histoire à l'usage des jeunes personnes",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000111',
#   'primary_author_name': 'Macquer, Philippe',
#   'full_book_title': "Annales romaines, ou Abrégé chronologique de l'histoire romaine, depuis la fondation de Rome jusqu'aux empereurs",
#   'stated_publication_years': '1756',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000112',
#   'primary_author_name': 'Castel de Saint-Pierre, Charles-Irénée',
#   'full_book_title': "Annales politiques de feu monsieur Charles Irénée Castel, abbé de St. Pierre, de l'Académie françoise",
#   'stated_publication_years': '1767',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000113',
#   'primary_author_name': "Arnaud, François-Thomas-Marie de Baculard [d']",
#   'full_book_title': 'Anne Bell: histoire anglaise  ',
#   'stated_publication_years': '1773',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000113',
#   'primary_author_name': "Arnaud, François-Thomas-Marie de Baculard [d']",
#   'full_book_title': 'Anne Bell: histoire anglaise ',
#   'stated_publication_years': '1770',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000114',
#   'primary_author_name': "Ardène, Jean-Paul de Rome [d']",
#   'full_book_title': "Année champêtre. Partie qui traite de ce qu'il convient de faire chaque mois dans le potager",
#   'stated_publication_years': '1770',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000115',
#   'primary_author_name': nan,
#   'full_book_title': "Année galante ou Etrenne à l'amour. Contes! Enrichis de figures et d'ariettes",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000116',
#   'primary_author_name': 'Fréron, Élie-Catherine',
#   'full_book_title': 'Année littéraire',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000118',
#   'primary_author_name': nan,
#   'full_book_title': "Anti-Chartreux (l'): Poême Chrétien",
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000119',
#   'primary_author_name': 'Frederick II, King of Prussia',
#   'full_book_title': 'Anti-Machiavel, ou Essai de critique sur le Prince de Machiavel',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000121',
#   'primary_author_name': 'Renoult, Jean-Baptiste',
#   'full_book_title': "Antiquité (l') et la perpétuité de la religion protestante",
#   'stated_publication_years': '1772',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000124',
#   'primary_author_name': 'Wall, Anton',
#   'full_book_title': "Antonie, ou l'auteur de Caroline, suivie de plusieurs pieces intéressantes, traduites de l'allemand, par Madame la chanoinesse de P.",
#   'stated_publication_years': '1787',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000125',
#   'primary_author_name': 'Servan, Joseph-Michel-Antoine',
#   'full_book_title': 'Apologie de la Bastille pour servir de réponse aux Mémoires de M. Linguet sur la Bastille... par un homme en pleine campagne',
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000126',
#   'primary_author_name': 'Salchli, Jean',
#   'full_book_title': "Apologie de l'histoire du peuple juif suivant les auteurs sacrés",
#   'stated_publication_years': '1770',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000127',
#   'primary_author_name': nan,
#   'full_book_title': 'Apologie du marquis de Fogliani, ci-devant vice roi de Naples',
#   'stated_publication_years': '1774',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000129',
#   'primary_author_name': 'Jouvency, Joseph de',
#   'full_book_title': "Appendix de Diis et heroibus poeticis, ou abrégé de l'histoire poétique",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000130',
#   'primary_author_name': 'La Roche, Charles [de]',
#   'full_book_title': 'Architecture hydraulique. Canal des deux mers, par M. de La Roche',
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000133',
#   'primary_author_name': 'Tissot, Samuel Auguste André David',
#   'full_book_title': 'Aristide, ou le citoyen',
#   'stated_publication_years': '1766-1767',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000137',
#   'primary_author_name': 'Le Gendre, François',
#   'full_book_title': "Arithmétique (l') en sa perfection, mise en pratique selon l'usage des financiers, banquiers et marchands... avec un traité de géométrie pratique appliquée à l'arpentage et au toisé... et un abrégé d'algèbre...; par F. Le Gendre",
#   'stated_publication_years': '1779',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000137',
#   'primary_author_name': 'Le Gendre, François',
#   'full_book_title': "Arithmétique (l') en sa perfection, mise en pratique selon l'usage des financiers, banquiers et marchands",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000138',
#   'primary_author_name': 'Guigoud-Pigale, Pierre',
#   'full_book_title': 'Arlequin à Genève: comédie en vers libres et en trois actes, par M. P. G. auteur du baquet magnétique',
#   'stated_publication_years': '1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000140',
#   'primary_author_name': 'Du Laurens, Henri-Joseph',
#   'full_book_title': "Arrétin (l') moderne",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000141',
#   'primary_author_name': nan,
#   'full_book_title': "Art (l') d'aimer et le remède d'amour d'Ovide",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000142',
#   'primary_author_name': 'Gouge de Cessières, François-Étienne',
#   'full_book_title': "Art (l') d'aimer, nouveau poëme en six chants, par Monsieur *****. Edition fidelle & complette, enrichie de figures",
#   'stated_publication_years': '1775',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000142',
#   'primary_author_name': 'Gouge de Cessières, François-Étienne',
#   'full_book_title': "Art (l') d'aimer, nouveau poëme en six chants",
#   'stated_publication_years': '1780',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000143',
#   'primary_author_name': 'Tissot [coiffeur]',
#   'full_book_title': "Traité de la nature des cheveux, et de l'art de coeffer",
#   'stated_publication_years': '1776',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000144',
#   'primary_author_name': 'Procope-Couteaux, Michel',
#   'full_book_title': "Art (l') de faire des garçons... Par M***, Docteur en Médecine de l’Université de Montpellier",
#   'stated_publication_years': '1779',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000144',
#   'primary_author_name': 'Procope-Couteaux, Michel',
#   'full_book_title': "Art (l') de faire des garçons, ou Nouveau tableau de l'amour conjugal. Par M.*** docteur en médecine de l'université de Montpellier",
#   'stated_publication_years': '1787',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000145',
#   'primary_author_name': 'Frederick II, King of Prussia',
#   'full_book_title': "Art (l') de la guerre, poëme en six chants",
#   'stated_publication_years': '1760',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000147',
#   'primary_author_name': nan,
#   'full_book_title': "[Art (l') de peindre au feu]",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000148',
#   'primary_author_name': 'Imhoof, Jean-Jacques',
#   'full_book_title': "Art (l') de tenir les livres en parties doubles, ou la science de faire écriture de toutes les négociations qui se font, soit en banque, soit en marchandises",
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000149',
#   'primary_author_name': 'Meerwein, Carl Friedrich',
#   'full_book_title': "Art (l') de voler à la manière des oiseaux, par Charles Frédéric Meerwein",
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000150',
#   'primary_author_name': "Buc'hoz, Pierre-Joseph",
#   'full_book_title': "Art (l') alimentaire, ou, Methode pour préparer les aliments les plus sains pour l'homme",
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000151',
#   'primary_author_name': 'Galiani, Ferdinando',
#   'full_book_title': "Art (l') de conserver les grains, par Barthélemy Inthiery, ouvrage traduit de l'italien par les soins de M. D. N. E.",
#   'stated_publication_years': '1770',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000152',
#   'primary_author_name': nan,
#   'full_book_title': nan,
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000155',
#   'primary_author_name': "Cailhava de L'Estandoux, Jean-François",
#   'full_book_title': "Art (de l') de la comédie, ou Détail raisonné des diverses parties de la comédie et de ses différents genres, suivi d'un traité de l'imitation, où l'on compare à leurs originaux les imitations de Molière et celles des modernes... terminé par l'exposition des causes de la décadence du théâtre et des moyens de le faire refleurir, par M. de Cailhava ",
#   'stated_publication_years': '1772',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000156',
#   'primary_author_name': 'La Forest, Nicolas Laurent',
#   'full_book_title': "Art (l') de soigner les pieds, contenant un traité sur les cors, verrues, durillons, oignons, engelures, les accidens des ongles et leur difformité... par M. Laforest",
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000158',
#   'primary_author_name': nan,
#   'full_book_title': 'Recueil des articles passés en loix, dans la principauté de Neuchâtel et Valangin depuis 1700: avec les articles généraux et particuliers accordés en 1707, et ceux accordés en 1768 ',
#   'stated_publication_years': '1775',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000159',
#   'primary_author_name': 'Tronson Du Coudray, Charles',
#   'full_book_title': "Artillerie (l') nouvelle, ou Examen des changements faits dans l'artillerie française depuis 1765, par M***",
#   'stated_publication_years': '1773',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000161',
#   'primary_author_name': 'Petit, Emilien',
#   'full_book_title': "Observations sur plusieurs assertions extraites littéralement de l'histoire philosophique des Etablissements européens dans les deux Indes",
#   'stated_publication_years': '1776',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000162',
#   'primary_author_name': nan,
#   'full_book_title': '[Atlas de la Crose]',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000163',
#   'primary_author_name': nan,
#   'full_book_title': '[Atlas des enfans]',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000164',
#   'primary_author_name': 'Bonnant, Jean Pierre',
#   'full_book_title': "Atrium latinitatis, ou recueil de mots latins à l'usage des écoliers",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000166',
#   'primary_author_name': nan,
#   'full_book_title': "Princesse (la) infortunée, ou Histoire d'Auréli",
#   'stated_publication_years': '1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000167',
#   'primary_author_name': 'Brissot de Warville, Jacques-Pierre',
#   'full_book_title': "Autorité (l') législative de Rome anéantie, ou Examen rapide de l'histoire et des sources du droit canonique",
#   'stated_publication_years': '1785',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000168',
#   'primary_author_name': 'Brenellerie, Paul-Phillipe Gaudin [de la]',
#   'full_book_title': "Aux mânes de Louis XV et des grandes hommes qui ont vécu sous son règne, ou essai sur les progrès des arts et de l'esprit humain, sous le règne de Louis XV",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000169',
#   'primary_author_name': 'Joly, Joseph-Romain',
#   'full_book_title': "Aventures (les) de Mathurin Bonice, premier habitant de l'isle de l'esclavage, ancien ministre du roi de Zanfara; tirées de ses mémoires, par un académicien des Arcades.",
#   'stated_publication_years': '1782-1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000170',
#   'primary_author_name': 'Renoult, Jean-Baptiste',
#   'full_book_title': "Aventures (les) de la Madonna et de François d'Assise, recueilles de plusieurs ouvrages des docteurs romains, écrites d'un style récréatif, en même temps capable de faire sentir le ridicule du papisme sans aucune controverse, par M. Renoult",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000171',
#   'primary_author_name': 'Leroy, Antoine',
#   'full_book_title': "Aventures (les) divertissantes du duc de Roquelaure: suivant les mémoires que l'auteur a trouvés dans le cabinet du maréchal d'H... / Par le S.L.R.",
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000171',
#   'primary_author_name': 'Leroy, Antoine',
#   'full_book_title': 'Momus (le) français, ou Les aventures divertissantes du duc de Roquelaure',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000172',
#   'primary_author_name': nan,
#   'full_book_title': "Aventures (les) galantes de quelques enfants de Loyola. Sur l'imprimé au Paraclet, 1782",
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000174',
#   'primary_author_name': 'Defoe, Daniel',
#   'full_book_title': 'Vie (la) et les aventures surprenantes de Robinson Crusoe, contenant son retour dans son Isle, ses autres nouveaux Voyages & ses Réflections',
#   'stated_publication_years': '1776',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000174',
#   'primary_author_name': 'Defoe, Daniel',
#   'full_book_title': 'Aventures de Robinson Crusoe',
#   'stated_publication_years': '1787',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000177',
#   'primary_author_name': 'Ramond de Carbonnières, Louis-François-Elisabeth',
#   'full_book_title': "Dernières (les) aventures du jeune d'Olban: fragment des Amours alsaciennes",
#   'stated_publication_years': '1777',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000179',
#   'primary_author_name': 'Vasse, Cornélie-Pétronille-Bénédicte Wouters [baronne de]',
#   'full_book_title': "Aveux (les) d'une femme galante, ou lettres de Madame la Marquise de ***, à Milady Fanny Stapelton",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000180',
#   'primary_author_name': 'Tissot, Samuel Auguste André David',
#   'full_book_title': 'Avis au peuple sur sa santé',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000182',
#   'primary_author_name': 'Pennington, Sarah',
#   'full_book_title': "Avis (les) d'une mère infortunée à ses filles, ouvrage nouvellement traduit de l'anglois... suivi de Fables morales, aussi traduites de l'anglois",
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000183',
#   'primary_author_name': 'Boissy, Louis [de]',
#   'full_book_title': 'Babillard (le), comédie de M. de Boissy',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000184',
#   'primary_author_name': nan,
#   'full_book_title': 'Bacha dans son serrail',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000185',
#   'primary_author_name': 'Lesage, Alain René',
#   'full_book_title': 'Bachelier (le) de Salamanque, ou les Mémoires et avantures de Don Chérubin de La Ronda',
#   'stated_publication_years': '1777',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000186',
#   'primary_author_name': nan,
#   'full_book_title': 'Bagatelle (la) du moment',
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000187',
#   'primary_author_name': 'Coyer, Gabriel-François',
#   'full_book_title': 'Bagatelles morales',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000187',
#   'primary_author_name': 'Coyer, Gabriel-François',
#   'full_book_title': 'Bagatelles morales',
#   'stated_publication_years': '1769',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000188',
#   'primary_author_name': nan,
#   'full_book_title': 'Bagatelles galantes',
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000189',
#   'primary_author_name': 'Genlis, Stéphanie Félicité [comtesse de]',
#   'full_book_title': "Bal d'enfans ou le duel, comédie en deux actes",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000190',
#   'primary_author_name': 'Du Laurens, Henri-Joseph',
#   'full_book_title': 'Balai (le), poème héroï-comique en XVIII chants',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000191',
#   'primary_author_name': "Huillier, Pierre [l']",
#   'full_book_title': 'Bannissement (le) des jésuites hors du royaume de France',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000192',
#   'primary_author_name': 'Guigoud-Pigale, Pierre',
#   'full_book_title': 'Baquet (le) magnetique, comédie, en vers et en deux actes. Par Mr. P.G.',
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000193',
#   'primary_author_name': 'Beaumarchais, Pierre Augustin Caron [de]',
#   'full_book_title': 'Barbier (le) de Séville, ou La Précaution inutile',
#   'stated_publication_years': '1775',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000193',
#   'primary_author_name': 'Beaumarchais, Pierre Augustin Caron [de]',
#   'full_book_title': 'Barbier (le) de Séville, ou La Précaution inutile, comédie en 4 actes, par M. de Beaumarchais, représentée sur le théâtre de la Comédie-Française le 23 février 1775',
#   'stated_publication_years': '1775',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000194',
#   'primary_author_name': 'Luchet, Jean-Pierre-Louis de La Roche du Marin [marquis de]',
#   'full_book_title': "Vicomte (le) de Barjac, ou mémoires pour servir à l'histoire de ce siècle, par M. C.... de L...., auteur des Liaisons dangereuses",
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000195',
#   'primary_author_name': "Arnaud, François-Thomas-Marie de Baculard [d']",
#   'full_book_title': "Batilde, ou l'Héroïsme de l'amour, drame en 5 actes et en vers, par M. Dysembart de La Fossardrie",
#   'stated_publication_years': '1775',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000197',
#   'primary_author_name': 'Baumeister, Friedrich Christian',
#   'full_book_title': '[Baumeister - unidentified work]',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000198',
#   'primary_author_name': 'Marmontel, Jean-François',
#   'full_book_title': 'Belisaire',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000199',
#   'primary_author_name': nan,
#   'full_book_title': '[Belle (la) et la Bête]',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000200',
#   'primary_author_name': 'Bret, Antoine',
#   'full_book_title': 'Belle (la) Allemande, ou les Galanteries de Thérèse',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000201',
#   'primary_author_name': 'Müller, Johannes [von]',
#   'full_book_title': 'Bellum Cimbricum descripsit Joannes Müller',
#   'stated_publication_years': '1772',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000202',
#   'primary_author_name': 'Meister, Leonhard',
#   'full_book_title': 'Beyträge zur Geschichte der teutschen Sprache',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000210',
#   'primary_author_name': 'Los-Rios, Jean-François [de]',
#   'full_book_title': 'Bibliographie instructive, ou Notice de quelques livres rares, singuliers & difficiles à trouver, avec des notes historiques, pour connoître & distinguer les différentes editions, & leur valeur dans le commerce; disposée par François de Los Rios, libraire à Lyon',
#   'stated_publication_years': '1777',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000215',
#   'primary_author_name': 'Vicat, Philippe Rodolphe',
#   'full_book_title': "Bibliothèque médico-physique du Nord, ou Recueil périodique de ce qu'il y a d'essentiel, d'intéressant et de plus nouveau",
#   'stated_publication_years': '1783-1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000216',
#   'primary_author_name': "Herbelot de Molainville, Barthélemy [d']",
#   'full_book_title': 'Bibliothèque orientale',
#   'stated_publication_years': '1780',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000219',
#   'primary_author_name': nan,
#   'full_book_title': "Bigarures (les) d'un citoyen de Genève et ses conseils républicains ...: Avec quantités d'Anecdotes amusantes ... et autres pour servir à terminer l`histoire des Jésuites",
#   'stated_publication_years': '1776',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000219',
#   'primary_author_name': nan,
#   'full_book_title': "[Bigarures (les) d'un citoyen de Genève]",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000220',
#   'primary_author_name': 'Diderot, Denis',
#   'full_book_title': 'Bijoux (les) indiscrets',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000222',
#   'primary_author_name': 'Boerhaave, Herman',
#   'full_book_title': 'Hermanni Boerhaave ... Praelectiones academicae de morbis nervorum, quas ex auditorum manuscriptis collectas edi curavit Jacobus van Eems',
#   'stated_publication_years': '1762',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000222',
#   'primary_author_name': 'Boerhaave, Herman',
#   'full_book_title': 'Praelectiones academicae de morbis nervorum',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000223',
#   'primary_author_name': 'Boerhaave, Herman',
#   'full_book_title': 'Hermanni Boerhaave... Methodus studii medici emaculata et accessionibus locupletata ab Alberto ab Haller',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000225',
#   'primary_author_name': 'Pomaret',
#   'full_book_title': 'Bon (le) père, ou Le Chrétien protestant',
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000226',
#   'primary_author_name': "Holbach, Paul Henri Dietrich [d']",
#   'full_book_title': 'Bon-Sens (le), ou idées naturelles opposées aux idées surnaturelles',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000226',
#   'primary_author_name': "Holbach, Paul Henri Dietrich [d']",
#   'full_book_title': 'Bon-sens (le), ou Idées naturelles opposées aux idées surnaturelles',
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000227',
#   'primary_author_name': 'Helvétius, Claude-Adrien',
#   'full_book_title': 'Bonheur (le), poème en six chants. Avec des fragments de quelques épîtres, ouvrages posthumes de M. Helvétius',
#   'stated_publication_years': '1773',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000228',
#   'primary_author_name': 'Théveneau de Morande, Charles',
#   'full_book_title': 'Bon-homme (le) anglois',
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000229',
#   'primary_author_name': 'Bonnet, Charles',
#   'full_book_title': '[Oeuvres de Bonnet]',
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000229',
#   'primary_author_name': 'Bonnet, Charles',
#   'full_book_title': '[Oeuvres de Bonnet]',
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000229',
#   'primary_author_name': 'Bonnet, Charles',
#   'full_book_title': '[Oeuvres de Bonnet]',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000229',
#   'primary_author_name': 'Bonnet, Charles',
#   'full_book_title': '[Oeuvres de Bonnet]',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000229',
#   'primary_author_name': 'Bonnet, Charles',
#   'full_book_title': '[Oeuvres de Bonnet]',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000230',
#   'primary_author_name': 'Mercier, Louis-Sébastien',
#   'full_book_title': 'Mon Bonnet de nuit',
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000230',
#   'primary_author_name': 'Mercier, Louis-Sébastien',
#   'full_book_title': 'Mon Bonnet de nuit',
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000230',
#   'primary_author_name': 'Mercier, Louis-Sébastien',
#   'full_book_title': '[Mon Bonnet de nuit]',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000233',
#   'primary_author_name': 'Bonnet, Charles',
#   'full_book_title': 'Essai de psychologie',
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000236',
#   'primary_author_name': nan,
#   'full_book_title': '[Bonnetre]',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000237',
#   'primary_author_name': 'Boškovic, Ruder Josip',
#   'full_book_title': "Journal d'un voyage de Constantinople en Pologne, fait à la suite de Son Excellence Mr Jaq. Porter, ambassadeur d'Angleterre, par le R. P. Joseph Boscowich... en 1762",
#   'stated_publication_years': '1772',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0000238',
# ...
#   'primary_author_name': 'Le Beau, Charles',
#   'full_book_title': 'Histoire du Bas-Empire: en commençant à Constantin le Grand',
#   'stated_publication_years': '1767-1781',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001136',
#   'primary_author_name': 'Jurieu, Pierre',
#   'full_book_title': 'Histoire du Calvinisme',
#   'stated_publication_years': '1773',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001137',
#   'primary_author_name': 'Voltaire, François Marie Arouet',
#   'full_book_title': 'Histoire de Charles XII, roi de Suède',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001141',
#   'primary_author_name': 'Faucher, Chrysostôme',
#   'full_book_title': 'Histoire du cardinal de Polignac',
#   'stated_publication_years': '1782',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001142',
#   'primary_author_name': nan,
#   'full_book_title': "Histoire du procès du chancelier Poyet, pour servir à celle du règne de François I... Avec un chapitre préliminaire sur l'antiquité et la dignité de l'office de chancelier, et sur les vicissitudes qu'il a éprouvées. Par l'historiographe sans gages et sans prétentions",
#   'stated_publication_years': '1776',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001143',
#   'primary_author_name': 'Prévost, Antoine François',
#   'full_book_title': 'Histoire du chevalier des Grieux, et de Manon Lescaut',
#   'stated_publication_years': '1753',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001144',
#   'primary_author_name': 'Sarpi, Paolo',
#   'full_book_title': 'Histoire du concile de Trente',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001147',
#   'primary_author_name': 'Raynal, Guillaume-Thomas-François',
#   'full_book_title': "Histoire du Parlement d'angleterre",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001148',
#   'primary_author_name': 'Voltaire, François Marie Arouet',
#   'full_book_title': 'Histoire du Parlement de Paris',
#   'stated_publication_years': '1773',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001149',
#   'primary_author_name': 'Maizonnet, Jean-Louis',
#   'full_book_title': "Histoire du peuple d'Israël, depuis la création du monde jusqu'au retour de la captivité de Babylone, tirée de l'Écriture sainte, par Jean-Louis Maizonnet",
#   'stated_publication_years': '1778-1779',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001150',
#   'primary_author_name': 'Racine, Jean',
#   'full_book_title': "Abrégé de l'histoire de Port-Royal",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001152',
#   'primary_author_name': nan,
#   'full_book_title': 'Histoire du siège de Cythère',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001153',
#   'primary_author_name': 'Brooke, Frances Moore',
#   'full_book_title': "Histoire d'Emilie Montague",
#   'stated_publication_years': '1770',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001154',
#   'primary_author_name': 'Eidous, Marc-Antoine',
#   'full_book_title': 'Histoire ecclésiastique ancienne et moderne, depuis la naissance de Jésus-Christ jusques au XVIIIe siècle... traduite en anglois, du latin de feu M. le baron de Mosheim... accompagnée de notes... par le Dr Archibald Maclaine. Édition traduite en français, sur la 2e édition anglaise',
#   'stated_publication_years': '1776',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001155',
#   'primary_author_name': 'Cousin-Despréaux, Louis',
#   'full_book_title': 'Histoire générale et particulière de la Grèce... par M. Cousin-Despréaux',
#   'stated_publication_years': '1780-1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001156',
#   'primary_author_name': 'Diderot, Denis',
#   'full_book_title': "Histoire générale des dogmes et opinions philosophiques, depuis les plus anciens temps jusqu'à nos jours, tirée du Dictionnaire encyclopédique",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001157',
#   'primary_author_name': 'Genlis, Stéphanie Félicité [comtesse de]',
#   'full_book_title': 'Histoire intéressante de Madame la duchesse de C***, écrite par elle-même',
#   'stated_publication_years': '1783',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001159',
#   'primary_author_name': 'Luchet, Jean-Pierre-Louis de La Roche du Marin [marquis de]',
#   'full_book_title': 'Histoire littéraire de M. de Voltaire, par M. le Mis de Luchet',
#   'stated_publication_years': '1781',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001160',
#   'primary_author_name': 'Sénebier, Jean',
#   'full_book_title': 'Histoire littéraire de Genève, par Jean Sénebier',
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001162',
#   'primary_author_name': 'May de Romainmotier, Emmanuel',
#   'full_book_title': "Histoire militaire des Suisses dans différens services de l'Europe par M. May-de-Romainmotier",
#   'stated_publication_years': '1772',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001163',
#   'primary_author_name': 'Hume, David',
#   'full_book_title': "Histoire naturelle de la religion, traduite de l'anglais de M. Hume",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001165',
#   'primary_author_name': 'Buffon, Georges-Louis Leclerc [comte de]',
#   'full_book_title': 'Histoire naturelle generale et particuliere',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001165',
#   'primary_author_name': 'Buffon, Georges-Louis Leclerc [comte de]',
#   'full_book_title': 'Histoire naturelle generale et particuliere',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001165',
#   'primary_author_name': 'Buffon, Georges-Louis Leclerc [comte de]',
#   'full_book_title': 'Histoire naturelle generale et particuliere',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001165',
#   'primary_author_name': 'Buffon, Georges-Louis Leclerc [comte de]',
#   'full_book_title': 'Histoire naturelle generale et particuliere',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001165',
#   'primary_author_name': 'Buffon, Georges-Louis Leclerc [comte de]',
#   'full_book_title': 'Histoire naturelle generale et particuliere',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001165',
#   'primary_author_name': 'Buffon, Georges-Louis Leclerc [comte de]',
#   'full_book_title': 'Histoire naturelle generale et particuliere',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001165',
#   'primary_author_name': 'Buffon, Georges-Louis Leclerc [comte de]',
#   'full_book_title': 'Histoire naturelle generale et particuliere',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001165',
#   'primary_author_name': 'Buffon, Georges-Louis Leclerc [comte de]',
#   'full_book_title': 'Histoire naturelle generale et particuliere',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001166',
#   'primary_author_name': 'Lediard, Thomas',
#   'full_book_title': "Histoire navale d'Angleterre depuis la conquête des Normands en 1666 jusqu'à la fin de l'année 1734... traduite de l'anglois de Thomas Lediard",
#   'stated_publication_years': '1751',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001167',
#   'primary_author_name': 'Targe, Jean-Baptiste',
#   'full_book_title': "Histoire nouvelle et impartiale d'Angleterre, depuis l'invasion de Jules César, jusqu'aux préliminaires de la paix de 1763, traduite de l'anglois de J. Barrow",
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001169',
#   'primary_author_name': 'Raynal, Guillaume-Thomas-François',
#   'full_book_title': 'Histoire philosophique et politique des isles françaises dans les Indes occidentales',
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001174',
#   'primary_author_name': 'Yvon, Claude',
#   'full_book_title': 'Histoire philosophique de la religion',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001178',
#   'primary_author_name': 'Gautruche, Pierre',
#   'full_book_title': "Histoire (l') poétique pour l'intelligence des poètes et des auteurs anciens",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001180',
#   'primary_author_name': 'Gibbon, Edward',
#   'full_book_title': "Histoire de la décadence et de la chute de l'Empire Romain",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001180',
#   'primary_author_name': 'Gibbon, Edward',
#   'full_book_title': "Histoire de la décadence et de la chute de l'Empire Romain",
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001180',
#   'primary_author_name': 'Gibbon, Edward',
#   'full_book_title': "Histoire de la décadence et de la chute de l'Empire Romain",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001180',
#   'primary_author_name': 'Gibbon, Edward',
#   'full_book_title': "Histoire de la décadence et de la chute de l'Empire Romain",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001180',
#   'primary_author_name': 'Gibbon, Edward',
#   'full_book_title': "Histoire de la décadence et de la chute de l'Empire Romain",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001181',
#   'primary_author_name': 'Crevier, Jean Baptiste Louis',
#   'full_book_title': "Histoire romaine, depuis la fondation de Rome jusqu'à la bataille d'Actium, c'est-à-dire jusqu'à la fin de la République, par M. Rollin",
#   'stated_publication_years': '1741',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001182',
#   'primary_author_name': 'Dubois, François-Nicolas',
#   'full_book_title': "Histoire secrète des femmes galantes de l'antiquité",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001183',
#   'primary_author_name': 'Lockhard, George',
#   'full_book_title': "Histoire secrète des intrigues de la France en diverses cours de l'Europe",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001184',
#   'primary_author_name': 'Hardion, J.',
#   'full_book_title': 'Histoire universelle: sacrée et profane',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001186',
#   'primary_author_name': 'Thou, Jaques-Auguste [de]',
#   'full_book_title': "Histoire universelle, Jacques Auguste de Thou; avec la suite par Nicolas Rigault; les Mémoires de la vie de l'auteur, un recueil de pièces concernant sa personne & ses ouvrages ...; le tout traduit sur la nouvelle édition latine de Londres; et augmenté de remarques historiques et critiques de Casaubon, de Du Plessis Mornay, G. Laurent, Ch. de L'Ecluse, Guy Patin, P. Bayle. J. Le Duchat, & autres; suivant la copie imprimée à Londres",
#   'stated_publication_years': '1742',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001187',
#   'primary_author_name': 'Leland, Thomas',
#   'full_book_title': "Histoire d'Irlande, depuis l'invasion d'Henri II, avec un Discours préliminaire sur l'ancien état de ce royaume, par Thomas Leland... traduite de l'anglois",
#   'stated_publication_years': '1779',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001191',
#   'primary_author_name': 'Guichenon, Samuel',
#   'full_book_title': "Histoire généalogique de la royale maison de Savoie, justifiée par titres, fondations de monastères... et autres preuves authentiques, par Samuel Guichenon... Nouvelle édition, avec des supplémens jusqu'à nos jours, suivis d'une dissertation contenant des remarques et additions... à cette histoire ",
#   'stated_publication_years': '1778',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001193',
#   'primary_author_name': nan,
#   'full_book_title': '[Historisch Aufsätze]',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001196',
#   'primary_author_name': 'Hoffmann, Friedrich',
#   'full_book_title': 'Friderici Hoffmanni Medicina consultatoria',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001199',
#   'primary_author_name': 'Verdy Du Vernois, Adrien-Marie-François [de]',
#   'full_book_title': 'Hommage à la vertu guerrière, ou Éloges de quelques-uns des plus célèbres officiers français qui ont vécu et qui sont morts sous le règne de Louis XV',
#   'stated_publication_years': '1779',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001201',
#   'primary_author_name': 'Helvétius, Claude-Adrien',
#   'full_book_title': "Homme (de l') de ses facultés intellectuelles et de son éducation",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001202',
#   'primary_author_name': 'Lignac, Matthieu [de]',
#   'full_book_title': "Homme (de l') et de la femme considérés physiquement dans l'état du mariage, par M. de Lignac",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001203',
#   'primary_author_name': nan,
#   'full_book_title': "[Homme (l')]",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001204',
#   'primary_author_name': 'Voltaire, François Marie Arouet',
#   'full_book_title': "Homme (l') aux quarante ecus",
#   'stated_publication_years': '1768',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001205',
#   'primary_author_name': 'Palissot de Montenoy, Charles',
#   'full_book_title': 'Homme dangereux: comédie',
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001206',
#   'primary_author_name': 'Bartoli, Daniello',
#   'full_book_title': "Homme (l') de lettres, par le P. Daniel Bartoli, ouvrage traduit de l'italien, augmenté de notes historiques et critiques, par le P. Delivoy",
#   'stated_publication_years': '1769',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001207',
#   'primary_author_name': 'Mercier, Louis-Sébastien',
#   'full_book_title': "Homme (l') de ma connaissance: comédie en deux actes, et en prose",
#   'stated_publication_years': '1781',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001208',
#   'primary_author_name': 'Mainvilliers, Genu Soalhat [chevalier de]',
#   'full_book_title': "Homme (l') dieu, ou l'univers seule famille. Poëme épique",
#   'stated_publication_years': nan,
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001209',
#   'primary_author_name': 'Levesque, Pierre-Charles',
#   'full_book_title': "Homme (l') moral, ou l'Homme considéré tant dans l'état de pure nature que dans la société, par P.-Ch. Levesque",
#   'stated_publication_years': '1775',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001210',
#   'primary_author_name': 'Jehin [abbé]',
#   'full_book_title': "Homme-sans-façon (l'); ou, Lettres d’un voyageur allant de Paris à Spa",
#   'stated_publication_years': '1786',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001211',
#   'primary_author_name': 'Mercier, Louis-Sébastien',
#   'full_book_title': "Homme (l') sauvage, histoire traduite de... par M. Mercier",
#   'stated_publication_years': '1784',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001212',
#   'primary_author_name': 'Gracián, Baltasar',
#   'full_book_title': "Homme (l') universel, traduit de l'espagnol de Baltasar Gracien",
#   'stated_publication_years': '1729',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001213',
#   'primary_author_name': 'Voltaire, François Marie Arouet',
#   'full_book_title': 'Homélie du pasteur Bourn, prêchée à Londres, le jour de la Pentecôte',
#   'stated_publication_years': '1768',
#   'illegal_date': nan},
#  {'super_book_code': 'spbk0001214',
#   'primary_author_name': 'Voltaire, François Marie Arouet',
#   'full_book_title': 'Honnêtetés (les) littéraires',
#   'stated_publication_years': '1767',
#   'illegal_date': nan},
#  ...]
